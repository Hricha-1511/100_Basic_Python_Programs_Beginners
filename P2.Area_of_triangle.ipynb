# %% [markdown]
# # Area of traingle using user input

# %%
height = float(input("Enter the height of the triangle:"))
base = float(input("ENTER THE base of the traingle:"))

area = (0.5)*base*height

print("The area of the triangle is: ", area)
# Out:
# Enter the height of the triangle:4
# ENTER THE base of the traingle:5
# The area of the triangle is:  10.0

# %% [markdown]
# # OR

# %% [markdown]
# # Area of traingle using user defined function

# %%
def area(height, base):
  area = (0.5)*base*height
  print("The area of the triangle is: ", area)


area(24,5)
# Out:
# The area of the triangle is:  60.0
