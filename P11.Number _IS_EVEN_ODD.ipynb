# %%
num = int(input("Enter a number u want to check if it is EVEN or IDD"))


if num %2==0:
  print(num,"Number u entered is EVEN")
else:
  print(num,"Number u entered is ODD")
# Out:
# Enter a number u want to check if it is EVEN or IDD7
# 7 Number u entered is ODD
