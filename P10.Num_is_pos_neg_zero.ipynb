# %%
num = int(input("Enter the value :"))

if num>0:
  print("Number is postive")
elif num<0:
  print("Number is negative")
else:
  print("Number is Zero")
# Out:
# Enter the value :0
# Number is Zero
