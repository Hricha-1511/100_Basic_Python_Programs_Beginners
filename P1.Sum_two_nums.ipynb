# %% [markdown]
# #Method  1
#
#  # Predefined Variables to perform the additon of two numbers

# %%
num1 = 23
num2 = 36

print('The sum of the two numbers is:', num1 + num2)
# Out:
# The sum of the two numbers is: 59

# %% [markdown]
# # OR

# %% [markdown]
# #Method  2
#
#  # User Input for defined Variables to perform the additon of two numbers

# %%
num1= int(input("Enter the first number: "))
num2 = int(input("Enter the second number:"))

sum = num1 + num2

print('The Sum of the two  numbers is :', sum)
# Out:
# Enter the first number: 1
# Enter the second number:2
# The Sum of the two  numbers is : 3

# %% [markdown]
# # OR

# %% [markdown]
# #Method   3
#
# #User Defined function to perform the addition of two numbers

# %%
def sum(num1, num2):
    sum = num1 + num2
    return sum

print('The Sum of the two numbers:', sum(2,3))
# Out:
# The Sum of the two numbers: 5
